# %%
# !pip install numpy
# !pip install matplotlib
# !pip install PILLOW
# 실행
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ## <미션1> 폴더내의 자료 확인
# - 파이썬 glob 명령어에 과  파이썬 os.listdir 의 차이점 정리
# - glob 또는 os.listdir 명령어를 이용하여 'flower.jpg' 파일의 작업 디렉토리에 있으면 '자료있음', 없으면' 자료없음'으로 출력

# %%
# [실행] - flower.jpg 파일이 있는지 확인
# glob명령어는 많이 사용되는 명령어임. 
# listdir 명령어와 어떤 차이가 있는지 확인하세요..
# Out:
# flower.jpg자료 있음

# %% [markdown]
# ## <미션2>  PIL 모듈을 이용한 이미지 load
# - PIL 모듈을 이용하여 flower.jpg 이미지 파일 열기
# - shape 확인
# - 이미지 파일을 array로 변환하여 이미지의 최소값, 최대값 확인
# - plt.imshow(  ) 명령으로 이미지 출력

# %%
# [실행]
# Out:
# (362, 227, 3)
# 0 255

# %% [markdown]
# ## <미션3>  이미지에 노이즈 추가 해석 및 실패요인 찾기
# - 코드 해석  np.random.normal(0.5,3.0 ,(362,227,3
# ![image-2.png](attachment:image-2.png)

# %%
noise=np.random.normal(0.5,3.0 ,(246522))## [미션 3-1] 코드 해석
print(noise[0,:2])  # 에러 요인만 파악
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [87], in <cell line: 2>()
#       1 noise=np.random.normal(0.5,3.0 ,(246522))## [미션 3-1] 코드 해석
# ----> 2 print(noise[0,:2])
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
# [미션] noise값을 362,227,3 으로 reshape함




print(noise[0,:2])  
print(noise.shape)

# %%
# 노이즈값이 추가된 결과물이 제대로 나올수 있도록 해결
plt.imshow(noise)
plt.show()

noise[noise>=0]=1    
noise[noise<0]=0


print(noise.min(), noise.max())
plt.imshow(imgArr+noise)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [86], in <cell line: 5>()
#       1 noise=np.random.normal(0.5,3.0 ,(246522))## [미션 3-1] 코드 해석
#       3 #noise=np.random.normal(0.5,3.0 ,(362,227,3))
# ----> 5 print(noise[0,:2])
#       6 print(noise.shape)
#       7 plt.imshow(noise)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %% [markdown]
# ## <미션4> 이미지 배열값 조정
# - tmp1=imgArr  과 tmp1=imgArr.copy() 의 차이점에 대하여 알기 # 구글검색, 파이썬 깊은복사
# - tmp1이미지 -> 이미지의 모든 배열숫자값이 200이상이면 0으로 변경함
# - tmp2이미지 -> 이미지의 모든 배열숫자값이 100이하이면 255로 변경함

# %%
tmp1=imgArr.copy()   # 
print(tmp1[0,:5])

# 미션:   tmp1이미지 -> 이미지의 모든 배열숫자값이 200이상이면 0으로 변경함



plt.imshow(a)
# Out:
# [[193 197 196]
#  [193 197 196]
#  [194 198 197]
#  [195 197 196]
#  [195 197 196]]

# %%
# 미션 : tmp2이미지 -> 이미지의 모든 배열숫자값이 100이하이면 255로 변경함
# tmp2로 이미지 복사후 실행
